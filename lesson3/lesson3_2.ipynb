# %% [markdown]
# curl http://localhost:11434/api/generate -d '{ "model": "llama3.2", "prompt":"Why is the sky blue?" }'

# %%
import requests

# 將您的 curl 命令轉換成 requests
url = "http://localhost:11434/api/generate"

# 準備請求的資料 (JSON 格式)
data = {
    "model": "gemma2:2b",  # 修正：使用實際可用的模型名稱
    "prompt": "Why is the sky blue?"
}

# 發送 POST 請求 (因為 curl 使用了 -d 參數)
response = requests.post(url, json=data)

# 檢查回應狀態
print(f"狀態碼: {response.status_code}")

# 取得回應內容
if response.status_code == 200:
    result = response.json()
    print("回應內容:")
    print(result)
else:
    print(f"請求失敗: {response.text}")
# Out:
# 狀態碼: 404
# 請求失敗: {"error":"model 'llama3.2' not found"}

# %%
# 另一種寫法：使用 data 參數而不是 json 參數
import requests
import json

url = "http://localhost:11434/api/generate"

# 方法1：使用 json 參數 (推薦)
data = {
    "model": "gemma3:1b",  # 修正：使用實際可用的模型名稱
    "prompt": "Why is the sky blue?"
}

try:
    response = requests.post(url, json=data)
    response.raise_for_status()  # 如果狀態碼不是 2xx，會拋出異常
    
    # Ollama API 返回的是流式響應，需要逐行解析
    print("成功取得回應:")
    for line in response.text.strip().split('\n'):
        if line:
            try:
                result = json.loads(line)
                print(result)
            except json.JSONDecodeError:
                print(f"無法解析的行: {line}")
                
except requests.exceptions.RequestException as e:
    print(f"請求發生錯誤: {e}")
except json.JSONDecodeError as e:
    print(f"JSON 解析錯誤: {e}")
    print(f"原始回應: {response.text}")
# Out:
# 成功取得回應:
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.0459826Z', 'response': 'The', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.0652122Z', 'response': ' sky', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.0831189Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1021289Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1216052Z', 'response': ' due', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1404785Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1587043Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1771838Z', 'response': ' phenomenon', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.1954504Z', 'response': ' called', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.2139295Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.2320123Z', 'response': 'Ray', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.2502729Z', 'response': 'leigh', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.2731408Z', 'response': ' scattering', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.2911423Z', 'response': '**.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.309644Z', 'response': ' Here', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.3279352Z', 'response': "'", 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.346337Z', 'response': 's', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.3689236Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.3897574Z', 'response': ' breakdown', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.4084631Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.4287401Z', 'response': ' how', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.4467569Z', 'response': ' it', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.4633331Z', 'response': ' works', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.4813349Z', 'response': ':', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5006767Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5185991Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5358835Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5537549Z', 'response': 'Sun', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5714155Z', 'response': 'light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.5888402Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.6069034Z', 'response': ' made', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.6245823Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.642489Z', 'response': ' all', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.6599719Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.676557Z', 'response': ' colors', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.6944195Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.7124265Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.7304046Z', 'response': ' rainbow', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.7538286Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.7708688Z', 'response': ' Think', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.7877313Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8060218Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8234664Z', 'response': ' prism', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8407792Z', 'response': ' splitting', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8585721Z', 'response': ' sunlight', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8753662Z', 'response': ' into', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.8929571Z', 'response': ' its', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.9098908Z', 'response': ' component', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.927073Z', 'response': ' colors', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.9447085Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.9628645Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:13.9816205Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0002575Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0171324Z', 'response': 'Sun', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0338068Z', 'response': 'light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0507208Z', 'response': ' enters', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0694512Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.0873797Z', 'response': ' Earth', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1044381Z', 'response': "'", 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1214646Z', 'response': 's', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1399056Z', 'response': ' atmosphere', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1568238Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1740974Z', 'response': ' The', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.1915822Z', 'response': ' atmosphere', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.2152267Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.2336765Z', 'response': ' filled', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.2522696Z', 'response': ' with', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.2689091Z', 'response': ' tiny', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.2865202Z', 'response': ' air', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3043089Z', 'response': ' molecules', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3215169Z', 'response': ' –', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3391777Z', 'response': ' primarily', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3566065Z', 'response': ' nitrogen', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3748959Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.3928014Z', 'response': ' oxygen', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.4100439Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.4279544Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.4485165Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.4658726Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.4839772Z', 'response': 'Blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.5023173Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.5198516Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.5371655Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.554398Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.5728636Z', 'response': ' than', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.5900626Z', 'response': ' other', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.607205Z', 'response': ' colors', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.6245722Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.641673Z', 'response': ' Rayleigh', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.659771Z', 'response': ' scattering', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.680934Z', 'response': ' happens', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.6990773Z', 'response': ' when', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.7174732Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.736107Z', 'response': ' coll', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.7527902Z', 'response': 'ides', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.7693259Z', 'response': ' with', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.7876025Z', 'response': ' particles', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.8041943Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.820941Z', 'response': ' scat', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.8383943Z', 'response': 'ters', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.855358Z', 'response': ' in', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.872378Z', 'response': ' different', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.8910913Z', 'response': ' directions', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.9100567Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.9268082Z', 'response': '  ', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.9446566Z', 'response': 'Blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.9622496Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.979996Z', 'response': ' violet', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:14.9982654Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.0150525Z', 'response': ' have', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.0311864Z', 'response': ' shorter', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.0474606Z', 'response': ' wavelengths', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.0657839Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.0831653Z', 'response': ' which', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.1005972Z', 'response': ' means', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.1189543Z', 'response': ' they', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.1443415Z', 'response': "'", 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.1621996Z', 'response': 're', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.1807903Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.199819Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.2177048Z', 'response': ' easily', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.2363047Z', 'response': ' by', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.2539021Z', 'response': ' these', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.2713948Z', 'response': ' tiny', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.2897566Z', 'response': ' air', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.3073189Z', 'response': ' molecules', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.3270025Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.344146Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.363099Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.3823886Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.3998767Z', 'response': 'We', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.4170398Z', 'response': ' see', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.4353988Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.4529951Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.4715073Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.4894043Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.5070861Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.5239352Z', 'response': ' Because', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.54091Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.5576837Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.5752491Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.5922759Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.616906Z', 'response': ' so', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.6347527Z', 'response': ' much', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.6514879Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.6693757Z', 'response': ' it', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.6859601Z', 'response': ' reaches', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7046911Z', 'response': ' our', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7216558Z', 'response': ' eyes', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7390205Z', 'response': ' from', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7567295Z', 'response': ' all', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7737136Z', 'response': ' directions', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.7907458Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8083634Z', 'response': ' making', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8268189Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8454118Z', 'response': ' sky', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8638722Z', 'response': ' appear', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8819251Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.8998187Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.9166866Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.9349359Z', 'response': '**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.9529695Z', 'response': 'Why', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.9711012Z', 'response': ' not', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:15.9893991Z', 'response': ' violet', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0077179Z', 'response': '?', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0254476Z', 'response': '**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0427158Z', 'response': ' Violet', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0608487Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0823479Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.0994929Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.1165651Z', 'response': ' even', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.1336926Z', 'response': ' *', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.1505192Z', 'response': 'more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.1677096Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.1844127Z', 'response': ' than', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2007994Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2181553Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2346087Z', 'response': ' but', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2519Z', 'response': ':', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2689244Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.2864691Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3038179Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3206954Z', 'response': 'Our', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3378948Z', 'response': ' eyes', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3546886Z', 'response': ' are', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3709524Z', 'response': ' less', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.3893284Z', 'response': ' sensitive', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4063735Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4232335Z', 'response': ' violet', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4402907Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4581737Z', 'response': '\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4759153Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.4932717Z', 'response': ' **', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.5110291Z', 'response': 'The', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.5414229Z', 'response': ' sun', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.5610466Z', 'response': ' emits', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.5790928Z', 'response': ' less', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.5971683Z', 'response': ' violet', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.6155384Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.6339112Z', 'response': '.**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.6504868Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.6676747Z', 'response': '**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.6844635Z', 'response': 'Think', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.7025079Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.7191649Z', 'response': ' it', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.7368561Z', 'response': ' like', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.754113Z', 'response': ' this', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.7736248Z', 'response': ':**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.7904437Z', 'response': ' Imagine', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8077268Z', 'response': ' throwing', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8251314Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8425879Z', 'response': ' small', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8602926Z', 'response': ' ball', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8787361Z', 'response': ' (', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.8972825Z', 'response': 'blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.9166306Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.9350112Z', 'response': ')', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.9535774Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.9704192Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:16.9878654Z', 'response': ' large', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.0071901Z', 'response': ' ball', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.0259714Z', 'response': ' (', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.0433821Z', 'response': 'red', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.0609592Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.078581Z', 'response': ')', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.0968676Z', 'response': ' at', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.1155292Z', 'response': ' a', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.1335139Z', 'response': ' bunch', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.1506277Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.1690199Z', 'response': ' tiny', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.1855869Z', 'response': ' obstacles', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.2043736Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.2222452Z', 'response': ' The', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.241059Z', 'response': ' small', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.2600124Z', 'response': ' ball', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.2774072Z', 'response': ' will', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.2952707Z', 'response': ' bounce', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.3135191Z', 'response': ' around', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.3320743Z', 'response': ' much', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.3496601Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.3666364Z', 'response': ' easily', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.3845357Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4029041Z', 'response': ' while', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4195818Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4377845Z', 'response': ' large', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4553897Z', 'response': ' ball', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4756909Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.4939369Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.5113621Z', 'response': ' likely', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.5293559Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.5477274Z', 'response': ' go', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.5665277Z', 'response': ' straight', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.5840738Z', 'response': ' through', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6013768Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6182023Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6356985Z', 'response': '**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6522529Z', 'response': 'Bonus', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6697937Z', 'response': ':**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.6866307Z', 'response': ' At', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7065485Z', 'response': ' sunset', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7239063Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7415054Z', 'response': ' sunrise', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7591907Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7762388Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.7937039Z', 'response': ' sunlight', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.8117528Z', 'response': ' has', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.8301951Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.8471177Z', 'response': ' travel', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.8657613Z', 'response': ' through', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.8831034Z', 'response': ' *', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9012039Z', 'response': 'more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9181436Z', 'response': '*', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9469577Z', 'response': ' atmosphere', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9636306Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9814547Z', 'response': ' reach', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:17.9982885Z', 'response': ' us', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.0152214Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.0322419Z', 'response': ' This', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.0497439Z', 'response': ' longer', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.0679432Z', 'response': ' path', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.085533Z', 'response': ' causes', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1028795Z', 'response': ' even', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1202197Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1370334Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1561603Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1741913Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.1914011Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.2089785Z', 'response': ' to', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.2267476Z', 'response': ' be', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.2446224Z', 'response': ' scattered', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.2629105Z', 'response': ' away', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.2815359Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.298101Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.3163418Z', 'response': ' we', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.3352166Z', 'response': ' see', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.3514787Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.3693212Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.3872987Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.4154735Z', 'response': ' red', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.4330255Z', 'response': ' and', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.4517832Z', 'response': ' orange', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.4692045Z', 'response': ' colors', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.4871864Z', 'response': ' of', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5052923Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5220493Z', 'response': ' sky', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5397894Z', 'response': '.', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5573472Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5752436Z', 'response': '---', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.5933056Z', 'response': '\n\n', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.6110213Z', 'response': '**', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.6290447Z', 'response': 'In', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.6490665Z', 'response': ' short', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.6660627Z', 'response': ',', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.6827859Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.7009783Z', 'response': ' sky', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.7194032Z', 'response': ' is', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.7384622Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.757373Z', 'response': ' because', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.7744966Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.7918915Z', 'response': ' air', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.8095262Z', 'response': ' molecules', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.8280994Z', 'response': ' in', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.8468856Z', 'response': ' our', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.8657692Z', 'response': ' atmosphere', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.8982093Z', 'response': ' scatter', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.9168509Z', 'response': ' blue', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.9344764Z', 'response': ' light', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.951982Z', 'response': ' from', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.9698987Z', 'response': ' the', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:18.988075Z', 'response': ' sun', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:19.0067256Z', 'response': ' more', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:19.0247168Z', 'response': ' than', 'done': False}
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T06:57:19.
531, 577, 29892, 3121, 236764, 532, 692, 1460, 919, 529, 506, 2604, 532, 11167, 7913, 529, 506, 7217, 236761, 108, 7243, 108, 1018, 902, 2822, 236764, 506, 7217, 563, 3730, 1547, 506, 2634, 13757, 528, 1023, 11661, 11887, 3730, 2214, 699, 506, 3768, 919, 1082, 1032, 7913, 99382, 108, 6294, 611, 1461, 531, 3449, 919, 1003, 236787, 108, 236829, 139, 818, 16505, 529, 121707, 19389, 236881, 107, 236829, 139, 11355, 112089, 659, 2604, 236786, 28975, 236881], 'total_duration': 6761256200, 'load_duration': 103507000, 'prompt_eval_count': 15, 'prompt_eval_duration': 100081800, 'eval_count': 364, 'eval_duration': 6556663200}

# %%
# 方法2：使用 data 參數 (需要手動轉換 JSON 字串)
import requests
import json

url = "http://localhost:11434/api/generate"

data = {
    "model": "gemma3:1b",  # 修正：使用實際可用的模型名稱
    "prompt": "Why is the sky blue?"
    
}

# 手動將字典轉換為 JSON 字串
json_data = json.dumps(data)

# 設定 Content-Type header
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, data=json_data, headers=headers)

print(f"狀態碼: {response.status_code}")
if response.status_code == 200:
    # Ollama API 返回的是流式響應，需要逐行解析
    print("回應內容:")
    for line in response.text.strip().split('\n'):
        if line:
            try:
                result = json.loads(line)
                print(result)
            except json.JSONDecodeError:
                print(f"無法解析的行: {line}")
else:
    print(f"請求失敗: {response.text}")
# Out:
# 狀態碼: 200
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\user\.conda\envs\langchain\Lib\site-packages\requests\models.py:965, in Response.json(self, **kwargs)
#     964 try:
# --> 965     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     966 except UnicodeDecodeError:
#     967     # Wrong UTF codec detected; usually because it's not UTF-8
#     968     # but some other 8-bit codec.  This is an RFC violation,
#     969     # and the server didn't bother to tell us what codec *was*
#     970     # used.
#
# File c:\Users\user\.conda\envs\langchain\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\user\.conda\envs\langchain\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 96)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 25
#      23 print(f"狀態碼: {response.status_code}")
#      24 if response.status_code == 200:
# ---> 25     result = response.json()
#      26     print("回應內容:")
#      27     print(result)
#
# File c:\Users\user\.conda\envs\langchain\Lib\site-packages\requests\models.py:973, in Response.json(self, **kwargs)
#     971             pass
#     972         except JSONDecodeError as e:
# --> 973             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     975 try:
#     976     return complexjson.loads(self.text, **kwargs)
#
# JSONDecodeError: Extra data: line 2 column 1 (char 96)

# %%
# 方法3：更好的處理方式 - 使用 stream 參數
import requests
import json

url = "http://localhost:11434/api/generate"

data = {
    "model": "gemma2:2b",
    "prompt": "Why is the sky blue?",
    "stream": False  # 設定為 False 以獲取完整回應
}

try:
    response = requests.post(url, json=data)
    response.raise_for_status()
    
    result = response.json()
    print("成功取得回應:")
    print(f"模型: {result.get('model', 'N/A')}")
    print(f"回應: {result.get('response', 'N/A')}")
    print(f"完成狀態: {result.get('done', False)}")
    
except requests.exceptions.RequestException as e:
    print(f"請求發生錯誤: {e}")
except json.JSONDecodeError as e:
    print(f"JSON 解析錯誤: {e}")
    print(f"原始回應: {response.text}")
